# %%
import pandas as pd
pd.options.display.max_rows = 10

df = pd.read_csv('Lorealinfalliblefoundationreview.csv', index_col=0)
df
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          Helpful                                              Title  \
# Verified
# yes          yes      The hype is real and I have mature, dry skin!
# yes          yes  This is one powder foundation to have in your ...
# yes          yes                Pleasantly surprised by this powder
# yes          yes                            MAYBE my new holy grail
# yes          yes                                Believe the hype!!!
# ...          ...                                                ...
# yes            -                          All the rage face powder!
# yes            -                       My opinion, not for dry skin
# yes            -             Great coverage with a lightweight feel
# yes            -                                              LOVE!
# yes            -                Who needs foundation in the summer?
#
#                                                        Body  Rating  \
# Verified
# yes       I am in my late 60s with normal to dry skin an...       5
# yes       This is one the best makeup products of the ye...       5
# yes       I have been wearing the True match (W3 or W4 i...       5
# yes       I really love this so far. Its VERY comparable...       5
# yes       I swear, I'm straight shook! I never believe t...       5
# ...                                                     ...     ...
# yes       My daughter loves this poweder! She’s always...       5
# yes       Well..its very cakey...BUT i figured how to us...       5
# yes       I saw this powder foundation on a video and to...       5
# yes       I thought it would just be a powder but was pl...       5
# yes       LOVE this stuff ... couple of swipes over mois...       5
#
#            Variation                       Style
# Verified
# yes       B08GR51PZG        Color Name: ivory 20
# yes       B08GR51PZG        Color Name: ivory 20
# yes       B08GR521VL       Color Name: linen 180
# yes       B08GR69H8P   Color Name: porcelaine 10
# yes       B08GR64MJ2  Color Name: true beige 130
# ...              ...                         ...
# yes       B08GR69H8P   Color Name: porcelaine 10
# yes       B08GR64MJ2  Color Name: true beige 130
# yes       B08GR51PZG        Color Name: ivory 20
# yes       B08GR64MJ2  Color Name: true beige 130
# yes       B08GR514T1        Color Name: sand 220
#
# [100 rows x 6 columns]

# %%
df.columns
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Index(['Helpful', 'Title', 'Body', 'Rating', 'Variation', 'Style'], dtype='object')

# %%
df.head()
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          Helpful                                              Title  \
# Verified
# yes          yes      The hype is real and I have mature, dry skin!
# yes          yes  This is one powder foundation to have in your ...
# yes          yes                Pleasantly surprised by this powder
# yes          yes                            MAYBE my new holy grail
# yes          yes                                Believe the hype!!!
#
#                                                        Body  Rating  \
# Verified
# yes       I am in my late 60s with normal to dry skin an...       5
# yes       This is one the best makeup products of the ye...       5
# yes       I have been wearing the True match (W3 or W4 i...       5
# yes       I really love this so far. Its VERY comparable...       5
# yes       I swear, I'm straight shook! I never believe t...       5
#
#            Variation                       Style
# Verified
# yes       B08GR51PZG        Color Name: ivory 20
# yes       B08GR51PZG        Color Name: ivory 20
# yes       B08GR521VL       Color Name: linen 180
# yes       B08GR69H8P   Color Name: porcelaine 10
# yes       B08GR64MJ2  Color Name: true beige 130

# %%
df['Body'].nunique()
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 100

# %%
# load library
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# download the set of stop words the first time
import nltk
nltk.download('stopwords')
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/syedazaima/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Load stop words
stop_words = stopwords.words('english')

# Show stop words
stop_words[:10]
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
#### Now creating some functions to do text processing
# Removing hashtags and mentions
def get_hashtags(text):
    hashtags = re.findall(r'\#\w+',text.lower())
    return hashtags
def get_mentions(text):
    mentions = re.findall(r'\@\w+',text.lower())
    return mentions

# Cleaning up the text of the tweets
def remove_content(text):
    text = re.sub(r"http\S+", "", text) #remove urls
    text=re.sub(r'\S+\.com\S+','',text) #remove urls
    text=re.sub(r'\@\w+','',text) #remove mentions
    text =re.sub(r'\#\w+','',text) #remove hashtags
    return text

def process_tweet(tweet):
    """ 
    tweets cleaning by 
    1) lowering the case of the tweet, 
    2) removing unwanted symbols and replacing them with a whitespace, 
    3) split sentences into words according to whitespaces and then 
    4) join back with a single whitespace as separator between various words
    """
    return " ".join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])", " ",tweet.lower()).split())

def process_text(text, stem=False): #clean text
    text=remove_content(text)
    lemmatizer=WordNetLemmatizer()
    text = re.sub('[^A-Za-z]', ' ', text.lower()) #remove non-alphabets
    text = re.sub(r'@[A-Za-z0-9]+', '', str(text)) # remove @mentions
    text = re.sub(r'#', '',  str(text)) # remove the '#' symbol
    text = re.sub(r'RT[\s]+', '',  str(text)) # remove RT
    text = re.sub(r'https?\/\/S+', '',  str(text)) # remove the hyperlink
    text = re.sub(r'http\S+', '',  str(text)) # remove the hyperlink
    text = re.sub(r'www\S+', '',  str(text)) # remove the www
    text = re.sub(r'twitter+', '',  str(text)) # remove the twiiter
    text = re.sub(r'pic+', '',  str(text)) # remove the pic
    text = re.sub(r'com', '',  str(text)) # remove the pic
    text = re.sub(r"\bamp\b", ' ', text.lower()) #remove "amp" which is coming from the translation of &
    text = re.sub(r"\bco\b", ' ', text.lower()) #remove "co" which was one of the top words found below
    tokenized_text = word_tokenize(text) #tokenize
    #tokenized_text = [lemmatizer.lemmatize(word) for word in tokenized_text]
    clean_text = [
         word for word in tokenized_text
         if (word not in stop_words and len(word)>1)
    ]
    if stem:
        clean_text=[stemmer.stem(word) for word in clean_text]
    clean_text = [lemmatizer.lemmatize(word) for word in clean_text]
    return ' '.join(clean_text)

#functions used to remove search terms from all the tweets
#function to remove duplicates from a string - in this case the string is the keywords used to scrape the tweets
def removeDupWithoutOrder(string): 
    words = string.lower().split()
    return " ".join(sorted(set(words), key=words.index)).replace('OR', '').replace('  ', ' ')

#function to search for string (i.e. tweet in this case) and remove specific words (search_terms in this case)
def remove_search(text, search_terms):
    query = text.lower()
    querywords = query.split()
    resultwords  = [word for word in querywords if word.lower() not in search_terms]
    return ' '.join(resultwords)

# define function to plot frequency of bi-grams, tri-grams, single words, phrases etc
from sklearn.feature_extraction.text import CountVectorizer
def plot_topn(sentences, ngram_range=(1,3), top=20,firstword=''):
    c=CountVectorizer(ngram_range=ngram_range)
    X=c.fit_transform(sentences)
    words=pd.DataFrame(X.sum(axis=0),columns=c.get_feature_names()).T.sort_values(0,ascending=False).reset_index()
    res=words[words['index'].apply(lambda x: firstword in x)].head(top)
    pl=px.bar(res, x='index',y=0)
    pl.update_layout(yaxis_title='count',xaxis_title='Phrases')
    pl.show('png')
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import re
re.compile('<title>(.*)</title>')
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# re.compile(r'<title>(.*)</title>', re.UNICODE)

# %%
# removing useless content (hashtags, mentions)
df['Body']=df['Body'].apply(lambda x: remove_content(x))
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df['cleaned_Body']=df['Body'].apply(lambda x: process_tweet(x))
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head()
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          Helpful                                              Title  \
# Verified
# yes          yes      The hype is real and I have mature, dry skin!
# yes          yes  This is one powder foundation to have in your ...
# yes          yes                Pleasantly surprised by this powder
# yes          yes                            MAYBE my new holy grail
# yes          yes                                Believe the hype!!!
#
#                                                        Body  Rating  \
# Verified
# yes       I am in my late 60s with normal to dry skin an...       5
# yes       This is one the best makeup products of the ye...       5
# yes       I have been wearing the True match (W3 or W4 i...       5
# yes       I really love this so far. Its VERY comparable...       5
# yes       I swear, I'm straight shook! I never believe t...       5
#
#            Variation                       Style  \
# Verified
# yes       B08GR51PZG        Color Name: ivory 20
# yes       B08GR51PZG        Color Name: ivory 20
# yes       B08GR521VL       Color Name: linen 180
# yes       B08GR69H8P   Color Name: porcelaine 10
# yes       B08GR64MJ2  Color Name: true beige 130
#
#                                                cleaned_Body
# Verified
# yes       i am in my late 60s with normal to dry skin an...
# yes       this is one the best makeup products of the ye...
# yes       i have been wearing the true match w3 or w4 in...
# yes       i really love this so far its very comparable ...
# yes       i swear i m straight shook i never believe the...

# %%
df.tail()
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          Helpful                                   Title  \
# Verified
# yes            -               All the rage face powder!
# yes            -            My opinion, not for dry skin
# yes            -  Great coverage with a lightweight feel
# yes            -                                   LOVE!
# yes            -     Who needs foundation in the summer?
#
#                                                        Body  Rating  \
# Verified
# yes       My daughter loves this poweder! She’s always...       5
# yes       Well..its very cakey...BUT i figured how to us...       5
# yes       I saw this powder foundation on a video and to...       5
# yes       I thought it would just be a powder but was pl...       5
# yes       LOVE this stuff ... couple of swipes over mois...       5
#
#            Variation                       Style  \
# Verified
# yes       B08GR69H8P   Color Name: porcelaine 10
# yes       B08GR64MJ2  Color Name: true beige 130
# yes       B08GR51PZG        Color Name: ivory 20
# yes       B08GR64MJ2  Color Name: true beige 130
# yes       B08GR514T1        Color Name: sand 220
#
#                                                cleaned_Body
# Verified
# yes       my daughter loves this poweder she s always tr...
# yes       well its very cakey but i figured how to use i...
# yes       i saw this powder foundation on a video and to...
# yes       i thought it would just be a powder but was pl...
# yes       love this stuff couple of swipes over moisturi...

# %%
df.describe()
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        Rating
# count   100.0
# mean      5.0
# std       0.0
# min       5.0
# 25%       5.0
# 50%       5.0
# 75%       5.0
# max       5.0

# %%
from wordcloud import WordCloud,ImageColorGenerator
from PIL import Image
import urllib
import requests
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
comment_words = '' 
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in df.cleaned_Body: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 1000, height = 800, 
                background_color='white', colormap='Set2', 
                collocations=False, 
                stopwords = stopwords, 
                min_font_size = 12).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (10, 10), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
df.to_csv("Cleaned_Body.csv")

# %%
import pandas as pd
import numpy as np
import string
import re
import nltk
from textblob import TextBlob
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
def getSubjectivity(text):
    return TextBlob( str(text)).sentiment.subjectivity

def getPolarity(text):
    return TextBlob( str(text)).sentiment.polarity

# %%
df.dropna(subset=['cleaned_Body'], inplace = True)
df.reset_index(drop=True, inplace=True)

# %%
df['Subjectivity'] = df['cleaned_Body'].apply(getSubjectivity)
df['Polarity'] = df['cleaned_Body'].apply(getPolarity)
df.head()
# Out:
#   Helpful                                              Title  \
# 0     yes      The hype is real and I have mature, dry skin!
# 1     yes  This is one powder foundation to have in your ...
# 2     yes                Pleasantly surprised by this powder
# 3     yes                            MAYBE my new holy grail
# 4     yes                                Believe the hype!!!
#
#                                                 Body  Rating   Variation  \
# 0  I am in my late 60s with normal to dry skin an...       5  B08GR51PZG
# 1  This is one the best makeup products of the ye...       5  B08GR51PZG
# 2  I have been wearing the True match (W3 or W4 i...       5  B08GR521VL
# 3  I really love this so far. Its VERY comparable...       5  B08GR69H8P
# 4  I swear, I'm straight shook! I never believe t...       5  B08GR64MJ2
#
#                         Style  \
# 0        Color Name: ivory 20
# 1        Color Name: ivory 20
# 2       Color Name: linen 180
# 3   Color Name: porcelaine 10
# 4  Color Name: true beige 130
#
#                                         cleaned_Body  Subjectivity  Polarity
# 0  i am in my late 60s with normal to dry skin an...      0.513137  0.115417
# 1  this is one the best makeup products of the ye...      0.600397  0.363095
# 2  i have been wearing the true match w3 or w4 in...      0.650000  0.310764
# 3  i really love this so far its very comparable ...      0.583683  0.184848
# 4  i swear i m straight shook i never believe the...      0.444444  0.063889

# %%
# Create a function to compute negative (-1), neutral (0) and positive (+1) analysis
def get_Polarity_Analysis(score):
    if score < 0:
      return 'Negative'
    elif score == 0:
      return 'Neutral'
    else:
      return 'Positive'
def get_Subjectivity_Analysis(score):
    if score >  0:
      return 'Opinion'
    else:
      return 'Fact'

df['Analysis_Polarity'] = df['Polarity'].apply(get_Polarity_Analysis)

df['Analysis_Subjectivity'] = df['Subjectivity'].apply(get_Subjectivity_Analysis)

# Show the dataframe
df.head()
# Out:
#   Helpful                                              Title  \
# 0     yes      The hype is real and I have mature, dry skin!
# 1     yes  This is one powder foundation to have in your ...
# 2     yes                Pleasantly surprised by this powder
# 3     yes                            MAYBE my new holy grail
# 4     yes                                Believe the hype!!!
#
#                                                 Body  Rating   Variation  \
# 0  I am in my late 60s with normal to dry skin an...       5  B08GR51PZG
# 1  This is one the best makeup products of the ye...       5  B08GR51PZG
# 2  I have been wearing the True match (W3 or W4 i...       5  B08GR521VL
# 3  I really love this so far. Its VERY comparable...       5  B08GR69H8P
# 4  I swear, I'm straight shook! I never believe t...       5  B08GR64MJ2
#
#                         Style  \
# 0        Color Name: ivory 20
# 1        Color Name: ivory 20
# 2       Color Name: linen 180
# 3   Color Name: porcelaine 10
# 4  Color Name: true beige 130
#
#                                         cleaned_Body  Subjectivity  Polarity  \
# 0  i am in my late 60s with normal to dry skin an...      0.513137  0.115417
# 1  this is one the best makeup products of the ye...      0.600397  0.363095
# 2  i have been wearing the true match w3 or w4 in...      0.650000  0.310764
# 3  i really love this so far its very comparable ...      0.583683  0.184848
# 4  i swear i m straight shook i never believe the...      0.444444  0.063889
#
#   Analysis_Polarity Analysis_Subjectivity
# 0          Positive               Opinion
# 1          Positive               Opinion
# 2          Positive               Opinion
# 3          Positive               Opinion
# 4          Positive               Opinion

# %%
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        Rating  Subjectivity    Polarity
# count   100.0    100.000000  100.000000
# mean      5.0      0.560596    0.309295
# std       0.0      0.203524    0.238605
# min       5.0      0.000000   -0.400000
# 25%       5.0      0.486538    0.180546
# 50%       5.0      0.575174    0.295673
# 75%       5.0      0.676389    0.433274
# max       5.0      1.000000    1.000000

# %%
df.to_csv("PolaritylorealReview.csv")
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Helpful                100 non-null    object
#  1   Title                  100 non-null    object
#  2   Body                   100 non-null    object
#  3   Rating                 100 non-null    int64
#  4   Variation              100 non-null    object
#  5   Style                  100 non-null    object
#  6   cleaned_Body           100 non-null    object
#  7   Subjectivity           100 non-null    float64
#  8   Polarity               100 non-null    float64
#  9   Analysis_Polarity      100 non-null    object
#  10  Analysis_Subjectivity  100 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 8.7+ KB

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(font_scale=2)

# %%
plt.figure(figsize=(15,10)) 

# plt.style.use('seaborn-pastel')

plt.scatter(df['Polarity'], df['Subjectivity'], c=df['Polarity'], s=100, cmap='RdYlGn') 

plt.xlim(-1.1, 1.1)
plt.ylim(-0.1, 1.1) 
plt.title('Sentiment Analysis') 
plt.xlabel('Polarity') 
plt.ylabel('Subjectivity') 
plt.show(),
# Out:
# (None,)

# %%
# Plotting and visualizing the counts
plt.figure(figsize=(15,10)) 

plt.title('Polarity Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
df['Analysis_Polarity'].value_counts().plot(kind = 'bar')
plt.show()

# %%
# Plotting and visualizing the counts
plt.figure(figsize=(15,10)) 

plt.title('Subjectivity Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
df['Analysis_Subjectivity'].value_counts().plot(kind = 'bar')
plt.show()

# %%
# Show the value counts
df['Analysis_Subjectivity'].value_counts()
# Out:
# Opinion    94
# Fact        6
# Name: Analysis_Subjectivity, dtype: int64

# %%
# !pip install pyLDAvis

import pyLDAvis
import pyLDAvis.gensim_models
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Requirement already satisfied: pyLDAvis in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (3.3.1)
# Requirement already satisfied: scikit-learn in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (0.23.2)
# Requirement already satisfied: pandas>=1.2.0 in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: scipy in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (1.5.2)
# Requirement already satisfied: future in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (0.18.2)
# Requirement already satisfied: setuptools in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (50.3.1.post20201107)
# Requirement already satisfied: numpy>=1.20.0 in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (1.22.3)
# Requirement already satisfied: funcy in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: gensim in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (4.1.2)
# Requirement already satisfied: joblib in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (0.17.0)
# Requirement already satisfied: numexpr in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (2.7.1)
# Requirement already satisfied: sklearn in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: jinja2 in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (2.11.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->pyLDAvis) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.2.0->pyLDAvis) (2.8.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.2.0->pyLDAvis) (2020.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from jinja2->pyLDAvis) (1.1.1)
# Requirement already satisfied: six>=1.5 in /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=1.2.0->pyLDAvis) (1.15.0)

# %%
tf_vectorizer = CountVectorizer(strip_accents = 'unicode',
                                stop_words = 'english',
                                lowercase = True,
                                token_pattern = r'\b[a-zA-Z]{3,}\b',
                                max_df = 0.5, 
                                min_df = 10)
dtm_tf = tf_vectorizer.fit_transform(df['cleaned_Body'].values.astype('U'))
print(dtm_tf.shape)
# Out:
# (100, 45)
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tfidf_vectorizer = TfidfVectorizer(**tf_vectorizer.get_params())
dtm_tfidf = tfidf_vectorizer.fit_transform(df['cleaned_Body'].values.astype('U'))
print(dtm_tfidf.shape)
# Out:
# (100, 45)
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:1796: UserWarning: Only (<class 'numpy.float64'>, <class 'numpy.float32'>, <class 'numpy.float16'>) 'dtype' should be used. <class 'numpy.int64'> 'dtype' will be converted to np.float64.
#   warnings.warn("Only {} 'dtype' should be used. {} 'dtype' will "

# %%
# for TF DTM
lda_tf = LatentDirichletAllocation(n_components =8, random_state=50)
lda_tf.fit(dtm_tf)
# for TFIDF DTM
lda_tfidf = LatentDirichletAllocation(n_components =8, random_state=50)
lda_tfidf.fit(dtm_tfidf)
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# LatentDirichletAllocation(n_components=8, random_state=50)

# %%
for i,topic in enumerate(lda_tf.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vectorizer.get_feature_names()[i] for i in topic.argsort()[-30:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['looks', 'oily', 'brush', 'cakey', 'wear', 'amazing', 'definitely', 'try', 'tone', 'doesn', 'little', 'don', 'skin', 'used', 'does', 'makeup', 'really', 'better', 'tried', 'color', 'smooth', 'liquid', 'love', 'best', 'foundation', 'day', 'great', 'use', 'coverage', 'powder']
#
#
# Top 10 words for topic #1:
# ['looks', 'looking', 'better', 'dry', 'apply', 'make', 'product', 'liquid', 'does', 'wear', 'cakey', 'oily', 'great', 'color', 'makeup', 'little', 'love', 'really', 'used', 'face', 'doesn', 'tried', 'don', 'skin', 'good', 'look', 'like', 'coverage', 'foundation', 'powder']
#
#
# Top 10 words for topic #2:
# ['really', 'looks', 'recommend', 'cakey', 'brush', 'apply', 'definitely', 'better', 'use', 'look', 'used', 'good', 'doesn', 'best', 'powder', 'day', 'looking', 'perfect', 'try', 'dry', 'ordered', 'amazing', 'love', 'just', 'coverage', 'tone', 'time', 'smooth', 'product', 'skin']
#
#
# Top 10 words for topic #3:
# ['coverage', 'dry', 'day', 'apply', 'cakey', 'oily', 'look', 'don', 'try', 'does', 'love', 'face', 'great', 'tone', 'perfect', 'ordered', 'really', 'just', 'recommend', 'skin', 'looks', 'little', 'liquid', 'looking', 'wear', 'powder', 'color', 'foundation', 'product', 'light']
#
#
# Top 10 words for topic #4:
# ['really', 'tone', 'definitely', 'ordered', 'recommend', 'powder', 'light', 'best', 'does', 'apply', 'cakey', 'perfect', 'amazing', 'wear', 'just', 'looking', 'like', 'love', 'good', 'foundation', 'smooth', 'tried', 'oily', 'use', 'product', 'skin', 'day', 'looks', 'coverage', 'great']
#
#
# Top 10 words for topic #5:
# ['powder', 'makeup', 'skin', 'oily', 'coverage', 'day', 'good', 'really', 'look', 'better', 'ordered', 'looks', 'does', 'tone', 'just', 'time', 'cakey', 'dry', 'color', 'little', 'wear', 'apply', 'liquid', 'brush', 'make', 'face', 'foundation', 'product', 'use', 'love']
#
#
# Top 10 words for topic #6:
# ['used', 'like', 'doesn', 'amazing', 'really', 'just', 'oily', 'brush', 'coverage', 'don', 'dry', 'little', 'does', 'liquid', 'makeup', 'ordered', 'product', 'try', 'day', 'good', 'time', 'face', 'make', 'great', 'foundation', 'powder', 'color', 'definitely', 'use', 'perfect']
#
#
# Top 10 words for topic #7:
# ['looks', 'really', 'doesn', 'great', 'product', 'tried', 'tone', 'definitely', 'apply', 'used', 'better', 'amazing', 'oily', 'just', 'cakey', 'use', 'make', 'look', 'like', 'liquid', 'does', 'dry', 'recommend', 'makeup', 'day', 'brush', 'coverage', 'powder', 'skin', 'foundation']
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
pyLDAvis.sklearn.prepare(lda_tf, dtm_tf, tf_vectorizer)
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 616, in wait_result_broken_or_wakeup
#     result_item = result_reader.recv()
#   File "/Users/syedazaima/opt/anaconda3/lib/python3.8/multiprocessing/connection.py", line 251, in recv
#     return _ForkingPickler.loads(buf.getbuffer())
# AttributeError: Can't get attribute '_unpickle_block' on <module 'pandas._libs.internals' from '/Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/internals.cpython-38-darwin.so'>
# """
#
# The above exception was the direct cause of the following exception:
#
# BrokenProcessPool                         Traceback (most recent call last)
# <ipython-input-55-db3dcce7638b> in <module>
# ----> 1 pyLDAvis.sklearn.prepare(lda_tf, dtm_tf, tf_vectorizer)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyLDAvis/sklearn.py in prepare(lda_model, dtm, vectorizer, **kwargs)
#      93     """
#      94     opts = fp.merge(_extract_data(lda_model, dtm, vectorizer), kwargs)
# ---> 95     return pyLDAvis.prepare(**opts)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyLDAvis/_prepare.py in prepare(topic_term_dists, doc_topic_dists, doc_lengths, vocab, term_frequency, R, lambda_step, mds, n_jobs, plot_opts, sort_topics, start_index)
#     437     term_frequency = np.sum(term_topic_freq, axis=0)
#     438
# --> 439     topic_info = _topic_info(topic_term_dists, topic_proportion,
#     440                              term_frequency, term_topic_freq, vocab, lambda_step, R,
#     441                              n_jobs, start_index)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyLDAvis/_prepare.py in _topic_info(topic_term_dists, topic_proportion, term_frequency, term_topic_freq, vocab, lambda_step, R, n_jobs, start_index)
#     274         ])
#     275
# --> 276     top_terms = pd.concat(Parallel(n_jobs=n_jobs)
#     277                           (delayed(_find_relevance_chunks)(log_ttd, log_lift, R, ls)
#     278                           for ls in _job_chunks(lambda_seq, n_jobs)))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1059
#    1060             with self._backend.retrieval_context():
# -> 1061                 self.retrieve()
#    1062             # Make sure that we get a last message telling us we are done
#    1063             elapsed_time = time.time() - self._start_time
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     938             try:
#     939                 if getattr(self._backend, 'supports_timeout', False):
# --> 940                     self._output.extend(job.get(timeout=self.timeout))
#     941                 else:
#     942                     self._output.extend(job.get())
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/opt/anaconda3/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                 raise CancelledError()
#     438             elif self._state == FINISHED:
# --> 439                 return self.__get_result()
#     440             else:
#     441                 raise TimeoutError()
#
# ~/opt/anaconda3/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# BrokenProcessPool: A result has failed to un-serialize. Please ensure that the objects returned by the function are always picklable.

# %%
topic_values = lda_tf.transform(dtm_tf)
topic_values.shape
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (100, 8)

# %%
# Statistical summary
df.describe().transpose()
# Out:
# /Users/syedazaima/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#               count      mean       std  min       25%       50%       75%  \
# Rating        100.0  5.000000  0.000000  5.0  5.000000  5.000000  5.000000
# Subjectivity  100.0  0.560596  0.203524  0.0  0.486538  0.575174  0.676389
# Polarity      100.0  0.309295  0.238605 -0.4  0.180546  0.295673  0.433274
#
#               max
# Rating        5.0
# Subjectivity  1.0
# Polarity      1.0
